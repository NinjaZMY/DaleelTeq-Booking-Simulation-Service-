# %% [markdown]
# ## `plan 1`

# %% [markdown]
# high priority is to test backend with db config
# however the datamodel is needed to be shown in the pms platform
# a datamodel progression file
# and then data model progression tasks including photos of each datamodel
# the best plan would be to include for each datamodel a task
# datamodel 1 datamodel 2 datamodel n etc
# and for the last data model
# backend generated datamodel 1 including the textual datamodel as screenshot + the mermaid generated from prompt8, the mermaid includes the datamodel of the backend generation
#
# to provide each datamodel I would have to check previous commits
# to not check commits manually I would click the file task1 and check history on github which will show changes of commits which facilitates finding the changes
#
# after preparing the data model progression file and then adding on pms platform each datamodel
#
# I can then easily move to testing the project
# in prompt 8, I should mention that I still haven't tested the backend

# %% [markdown]
# ## `task 1`

# %% [markdown]
# -[x] create datamodel progression file having each mermaid code + photo of the datamodel
# -[x] for each datamodel create a pms task with screenshots, having the last datamodel task including two screenshots of datamodel + textual datamodel that shows datamodel relationships generated by copilot
#     -[x] for the last datamodel (mermaid), prepare a prompt for copilot erd diagram from the entities with commentary on each attribute, in the prompt ask copilot to provide textual representation before proceeding to generate the mermaid file, the textual representation will be turned if confirmed into mermaid
#         -[x] generate the mermaid datamodel

# %% [markdown]
# ## `task 1 Result`

# %% [markdown]
# Finished successfully but not within the task order (optimal resolution)
