# %% [markdown]
# ## `prompt 1`

# %% [markdown]
# when cancelling an R, ES.status must be back to "free" so that it can be booked again , the N created will inherit the R.status that states which cancellation a cancellation by C or E
# 1. 2. confirmed
# 3. PUT also includes apart its id counterpart a put/entity where the json must include the right id for update or else the user will be informed which ids to use from etc...
#  just like put delete also has the /id and the /entity where the json provides the right id or else the user will be shown a list etc...
# 4. I don't understand can you explain with max details
# 5. I want the information to be shown on the webpage, the user must see the id list for testing which error or whether the api transaction went correctly or not, the response doesn't have to be an error more like error handling, I'm interested in the webpage showing directly what's up or wrong without the need to check the console or switch the tab so that my testing on postman can go smoothly and efficiently without compromise
# 6. all the generated files must be functional that I can run the springboot project and it runs smoothly

# %% [markdown]
# ## `prompt 2`

# %% [markdown]
# After we finish the backend confirmation
# we will step into creating the frontend with Angular 21.0.1 Node.js 24.11.1
# package manager npm 11.6.4 knowing that my os is win32 x64
# for the front-end I  will be guiding you step by step
# for example so that the tests can be easily done inserting into the database 10 employees (E) each having lib from E0 to E9
# the index page will have as view in the homepage the following:
# all of it might be done in one component or many knowing that each item in the frontend will depend to another as a holistic design
# at first we're going to add employees into views but it's not going to be a simple listing at first it might be
#
# Step1
# Employees (E) will be loaded
# it's going to be for each employee example from E0 to E9
# each E will be a clickable button
# and only one E can be selected at a time
# When E is selected the clickable button will be highlighted
# in the later steps the selection of E will load data from the db
# the data might differ for each E
# Step2
# E will be loaded by pagination
# with button of pages too
# each page having 5 E
# for example in page 1 it loads E0 ro E4
# page 2 when clicked loads E5 to E9
# the pagination technique will/might be further used for the other upcoming items / entities later on in the later steps
#
# of course before you do anything you need to be confirming everything with me so that things can be clear and plans can be executed smoothly
