# %% [markdown]
# ## `prompt 2`

# %% [markdown]
# when cancelling an R, ES.status must be back to "free" so that it can be booked again , the N created will inherit the R.status that states which cancellation a cancellation by C or E
# 1. 2. confirmed
# 3. PUT also includes apart its id counterpart a put/entity where the json must include the right id for update or else the user will be informed which ids to use from etc...
#  just like put delete also has the /id and the /entity where the json provides the right id or else the user will be shown a list etc...
# 4. I don't understand can you explain with max details
# 5. I want the information to be shown on the webpage, the user must see the id list for testing which error or whether the api transaction went correctly or not, the response doesn't have to be an error more like error handling, I'm interested in the webpage showing directly what's up or wrong without the need to check the console or switch the tab so that my testing on postman can go smoothly and efficiently without compromise
# 6. all the generated files must be functional that I can run the springboot project and it runs smoothly

# %% [markdown]
# ## `prompt 3`

# %% [markdown]
# you made a big mistake in analyzing the datamodel which is saying things like EmployeeShift,Reservation when it was mentioned in the datamodel comments and the initial prompt what is the right signification which is
# E for Employee, S services , ES Employee_x_Services , R Rendez_vous , C Client
# 1. include lombok
# 2. 3 4 5 and almost all steps etc...  change as above
# 2. ES has date column which you might have referred to as timeValue, I prefer date why have you set it as enum allowed set when it's a date format of YYYY/MM/DD confirm with me and ask me if necessary
# date is necessary here confirm with me
# for R the FK should be ES_id also you made a big mistake since you included a Client name instead of the Client_id, it should be client_id since there's no way for the client to cancel without the client_id and people can have similar names in many cases that's a very big mistake also ES for data efficiency doesn't conserve Client_id if you didn't catch that detail
# you can tell me why you chose clientName why my method or your method is better; ask me if necessary; tell me what happens if we go on your suggestion and what happens if we go on my suggestion; confirm with me before you proceed
# Rendez_vousService what's the difference between book and validate what does each do; I need to understand before proceeding for now the R doesn't need another confirmation for it to be active when booked confirm with me and ask me
# what's query in NotificationService
# 3. would also need CRUDs for E , S why wasn't that included
# the route should be ES or Employee_x_Services
# 4. on validation if timestamp is invalid or date is invalid provide valid timestamps intervals or valid date intervals
# 5. why haven't you included X_2 into ES it should be included if 1 it will include the double duration of the service meaning a bigger timeslot or else normal duration; even in the Notification it can be included that it's a double duration from start to end; a single ES row
# 6. what's the database creation with credentials I don't get it; if it's possible you shouldn't create a password; and if you see creating a password is the better choice tell me why and why keep it without password isn't ideal; before you proceed confirm with me
# 7. should include all tables CRUD for functionality and for easier testing
# 10. need client_id for R
#
# should be for R api/rendezvous
# ID type bigserial
# X_2 single row doubled duration
#
#
# before you proceed to each step confirm with me and ask me to see if we're on the same page for a smoother smoothest experience

# %% [markdown]
# ## `prompt 4`

# %% [markdown]
# 2a >
# 1. option A date with start and end
# 2. because it's easier to compute this way since later on you might have to search the date to delete rows or simply search for available dates at a single date since later in the app we will implement a calendar
# a timestamp however has additional non needed data like time while our app values both date and time separated
# 2c.
# go with the recommendation
# 2d. option A Auto-active
# 3.  we need to have post for N to test Notification creation
# we need to create a button or something that deletes all rows of a table from each entity for example : DeleteAllNotifications and other deleteAllTableNameRows etc...
# add another button or something that deletes all the rows from all tables of the database maybe call it
# ClearDB
# for each button that clears table rows or all the database table rows before it's executed the user needs to confirm such action
# use api/ES
# 4. when validation fails the error response should be exact ; precise and detailed
# if the user wrote invalid time intervals the message will print Valid time for example from 0800 to 1700
# if user inputted wrong date the error message will show the right date interval
# the error message shouldn't be generic indicating all possible errors it should be precise
# only indicating the errors the user committed with the input
# if the user only  wrote wrong timestamp
# the error message will only show the correct timestamp interval
# only when the user committed all the errors that the error message will print the mitigation to all errors
# if user made 2 errors the error msg will show the mitigation of 2 errors showing that the input is invalid for example 18:15 is invalid it should between 0800 and 1700
# confirm with me before you proceed to see whether you clearly understand my intent
# 5. add time value to ES that inherits S timevalue and if x_2 timevalue gets doubled
# 6. option b with gitignore for the env file and another file that can be uploaded to git which is example.env which is a template for the env file so that the users will know what to expect in the env file
# env file must be created
# for .env.example it would include something like this:
# # Database Credentials Template
# DB_USERNAME=
# DB_PASSWORD=
# for the .gitignore file it would contain something like this:
# # Security: Ignore environment variables
# .env
#
# # Optional: Ignore other sensitive files
# *.local
# target/
# .mvn/
#
# apart from everything when the files are loaded intellij need to be/should be able to detect the project and be able to launch maven tools
# because I don't have maven installed system wide and rely on intellij's maven
#
# before you proceed to anything confirm with me each step and point and ask me questions if necessary
# if you're ready to proceed tell me

# %% [markdown]
# ## `prompt 5`

# %% [markdown]
# to answer your questions before we go any further:
# 1. route would be api/es with case insensitive routing so that ES eS and all alternatives will be accepted
# 2. I confirm and prefer the env file to be created and be included in the gitignore .env.example should include a first comment saying: that this file means that this project require an .env file following this template
# 3. confirm
# 4. I pick testcontainers We will use the "Singleton Pattern" or "Reusable Containers" so the database starts once and stays alive for all tests, making it nearly as fast as H2 after the first startup.
# 5. confirm
#
# for time_value:
# add column to ES that is time_value on ES creation ES inherits the S timevalue and if ES has x_2 time_value gets the double value or else normal value
# adding time_value to ES will make the time computation is easier
# ES.time_value persists on ES
#
# should include hot reload for springboot
# so that the user doesn't re-run the springboot project on code change
# requiring one springboot run
#  something like:
#  spring.devtools.livereload.enabled=true
# spring.devtools.restart.enabled=true
# spring.devtools.restart.additional-paths=src/,resources/application.properties
# spring.devtools.restart.exclude=**/static/**, **/public/**, **/templates/**, **/META-INF/maven/**, **/META-INF/resources/**, **/resources/**, **/META-INF/**, **/logback.xml, **/logback-spring.xml
# ----
# the livereload must work perfectly so that one single run of the project and with eternal code change it still works
#
#
# before you proceed confirm with me what is yet to be confirmed like the new input of my prompt and new information yet to be confirmed

# %% [markdown]
# ## `prompt 6`

# %% [markdown]
# 1. we can tell spring to ignore the case via:
# @Configuration
# ```java
# public class WebConfig implements WebMvcConfigurer {
#     @Override
#     public void configurePathMatch(PathMatchConfigurer configurer) {
#         AntPathMatcher matcher = new AntPathMatcher();
#         matcher.setCaseSensitive(false); // This is the "magic" line
#         configurer.setPathMatcher(matcher);
#     }
# }
# ```
# right?
# this seems better than your solution; confirm with me this what do you think and is this ideal
# the case insensitive should be for all urls
# and stick to api/es
#
# 2. B. auto load
#
# is the hot reload config I provide okay or does it need further refinement or tuning ?
#
# confirm with 1. and the new point before we proceed

# %% [markdown]
# ## `prompt 7`

# %% [markdown]
# A. B C confirm
# confirm: implement .env loader with merge fallback to OS env vars
# Proceed

# %% [markdown]
# ## `prompt 8`

# %% [markdown]
# By the way I still haven't tested the backend yet
# maven wrapper is lacking or should I install mvn locally
# I prefer mvn locally
# readme table of content links are broken they don't link to each section when clicked
# I want to test the unit tests and then move to integration tests
# reusable singleton pattern
# it should be idES not idEs
# can you generate a mermaid file of the datamodel while keeping the same/similar/better semantics/comments of the datamodel.mmd file in my repository
# highest priority is the mermaid file generation before you proceed to generate the mermaid file confirm with me
# before you proceed to create the mermaid file confirm with me by providing me a textual representation of the erd diagram which has all semantics included I want the entities to be preserved with their attributes and having the right semantics , the current datamodel.mmd has some good semantics (it's the old datamodel before the backend generation) but what I require is semantics to each attribute while true to the entities of the backend
# so to confirm with me the validity of the mermaid file before generation you should provide me with a textual representation
# similar to erd what you will do exactly is provide me with
# mermaid erd diagram text for me to review before you generate the file
# you do not generate the datamodel.mmd file unless I confirm with you the validity of the mermaid code that you will provide immediately in the response to this prompt
#
#
# before you do anything confirm with me so that the work can be smooth

# %% [markdown]
# ## `prompt 9`

# %% [markdown]
# after I confirm the points below proceed to regenerate the mermaid erd code
# (updating semantics)
# requiring confirmation before you proceed to generate the mermaid file
#
# 1. DB uses snake_case
# java uses camelCase having id_C id_E id_ES id_R id_S etc...
#
# 2. all PKs as BigSerial
#
# 6. x_2 and time_value must be included in N for clarity and ease of calculations
#
# 7. routes confirmed
#
# 9. I already answered this before by saying
# dedicated DB user with password which you did provide me
# some code to start it
# ### Step 1: PostgreSQL 18 Setup (5 min)
# ```bash
# psql -U postgres
# CREATE DATABASE booking_db;
# CREATE USER booking_user WITH PASSWORD 'changeme';
# GRANT ALL PRIVILEGES ON DATABASE booking_db TO booking_user;
# \q
# psql -U booking_user -d booking_db -f src/main/resources/db/schema-postgres18.sql
# ```
# Response to questions before you proceed:
# 3. 09-16
# 6. add maven wrapper
#
#
# for 1.
# confirm with me everything before you proceed

# %% [markdown]
# ## `prompt 10 - 11`

# %% [markdown]
# Confirm erd

# %% [markdown]
# ## `prompt 12`

# %% [markdown]
# Confirm erd you can generate the erd file
# for the time window you can make start time and end time as variables, and make it 09-16 for now with the possibility of modifying such date
# before you proceed to generate the backend files show me how all variable of entities will be shown

# %% [markdown]
# ## `prompt 13`

# %% [markdown]
# java should use idES (idES in DTOs)
# java entity ES_Notification or Notification
# DeleteALL and clear-db must use client side dialog to confirm without typed confirmation token
# DeleteALL or clear-db must also exist as buttons
# for Rendez_vous it's IdES not idEs
# why do you make me repeat myself countless times when I stated idES (idES is here for java not for db snake_case) many times as required which will not invalidate current rules and be just the exception to the rule
# the other variables are alright

# %% [markdown]
# ## `prompt 14`

# %% [markdown]
# 2. Notification
# confirmed

# %% [markdown]
# ## `prompt 15`

# %% [markdown]
# This was the second project generation (backend)
# the problem is that there are still files from the first generation that weren't discarded
# which were still there would cause errors and conflicts , should have checked files before generation focusing on editing rather than generating all which seems to be partially true however some conflict files
# EmployeeServiceRestController.java seems to have errors using old version files of EmployeeServiceService.java (which I proceeded to empty than delete)
# EmployeeServiceService.java seems to be deprecated since its from the first file generation
# maybe EmployeeServiceRestController.java should be updated because maybe the current version didn't generate rest files I'm not sure
# the right file EmployeeXServiceService.java seems to be erroneous

# %% [markdown]
# ## `prompt 16`

# %% [markdown]
# A)

# %% [markdown]
# ## `prompt 17`

# %% [markdown]
# you didn't quite fix everything as
# RendezVousRestController.java and EmployeeServiceRestController.java are just rendered deprecated
# without adding the correct RestControllers for both Employee_x_Services(EmployeeXService) & Rendez_vous

# %% [markdown]
# ## `prompt 18`

# %% [markdown]
# DotenvEnvironmentPostProcessor and EmployeeRestController both show errors

# %% [markdown]
# ## `prompt 19`

# %% [markdown]
#     you haven't fixed all errors for DotenvEnvironmentPostProcessor
#     import io.github.cdimascio.dotenv.Dotenv; is flagged as wrong because Cannot resolve symbol 'github'
#     'org.springframework.boot.env.EnvironmentPostProcessor' is deprecated since version 4.0.0 and marked for removal
#     Cannot resolve symbol 'Dotenv'
#     Cannot resolve method 'get(String)'
#
#
#     also for each file check errors if errors exist fix

# %% [markdown]
# ## `prompt 20`

# %% [markdown]
# You still haven't fixed all errors of all files
# for example WebConfig:
# 'setPathMatcher(org.springframework.util.PathMatcher)' is deprecated since version 7.0 and marked for removal

# %% [markdown]
# ## `prompt 21`

# %% [markdown]
# I still haven't configured the database but wanted to test the app
# here's compilation log about errors: by mvn test
# [INFO]
# [INFO] --- compiler:3.14.1:compile (default-compile) @ booking-simulation-service ---
# [INFO] Recompiling the module because of added or removed source files.
# [INFO] Compiling 51 source files with javac [debug parameters release 25] to target\classes
# [INFO] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/exception/GlobalExceptionHandler.java: C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\exception\GlobalExceptionHandler.java uses or overrides a deprecated API.
# [INFO] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/exception/GlobalExceptionHandler.java: Recompile with -Xlint:deprecation for details.
# [INFO] -------------------------------------------------------------
# [ERROR] COMPILATION ERROR :
# [INFO] -------------------------------------------------------------
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/BookingApplication.java:[12,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.BookingApplication
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/BookingApplication.java:[14,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.BookingApplication
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[36,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[57,29] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[61,17] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[63,17] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[66,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[78,17] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/config/DotenvEnvironmentPostProcessor.java:[81,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.config.DotenvEnvironmentPostProcessor
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/ClientController.java:[43,16] cannot find symbol
#   symbol:   method getId()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/ClientController.java:[47,55] cannot find symbol
#   symbol:   method getId()
#   location: variable c of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/ClientController.java:[51,64] cannot find symbol
#   symbol:   method getId()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/ClientController.java:[62,16] cannot find symbol
#   symbol:   method getId()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/ClientController.java:[66,55] cannot find symbol
#   symbol:   method getId()
#   location: variable c of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/ClientController.java:[70,39] cannot find symbol
#   symbol:   method getId()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[27,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[37,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[41,21] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[53,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[53,48] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[55,31] cannot find symbol
#   symbol:   method builder()
#   location: class com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[56,25] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[57,28] cannot find symbol
#   symbol:   method getNumber()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[61,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[61,66] cannot find symbol
#   symbol:   method getId()
#   location: variable saved of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[69,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[74,21] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[80,16] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[81,30] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[83,16] cannot find symbol
#   symbol:   method getNumber()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[84,33] cannot find symbol
#   symbol:   method getNumber()
#   location: variable dto of type com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[88,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[88,68] cannot find symbol
#   symbol:   method getId()
#   location: variable updated of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[96,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[100,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[107,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[114,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[116,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ClientService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[124,43] cannot find symbol
#   symbol:   method getId()
#   location: variable c of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[125,17] no suitable method found for collect(java.util.stream.Collector<java.lang.CharSequence,capture#1 of ?,java.lang.String>)
#     method java.util.stream.Stream.<R>collect(java.util.function.Supplier<R>,java.util.function.BiConsumer<R,? super java.lang.Object>,java.util.function.BiConsumer<R,R>) is not applicable
#       (cannot infer type-variable(s) R
#         (actual and formal argument lists differ in length))
#     method java.util.stream.Stream.<R,A>collect(java.util.stream.Collector<? super java.lang.Object,A,R>) is not applicable
#       (cannot infer type-variable(s) R,A
#         (argument mismatch; java.util.stream.Collector<java.lang.CharSequence,capture#2 of ?,java.lang.String> cannot be converted to java.util.stream.Collector<? super java.lang.Object,A,R>))
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[132,25] cannot find symbol
#   symbol:   method builder()
#   location: class com.daleelteq.booking.dto.ClientDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[133,27] cannot find symbol
#   symbol:   method getId()
#   location: variable client of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[134,28] cannot find symbol
#   symbol:   method getLib()
#   location: variable client of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[135,31] cannot find symbol
#   symbol:   method getNumber()
#   location: variable client of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ClientService.java:[136,34] cannot find symbol
#   symbol:   method getCreatedAt()
#   location: variable client of type com.daleelteq.booking.domain.Client
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/DatabaseController.java:[38,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.controller.DatabaseController
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/DatabaseController.java:[49,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.controller.DatabaseController
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/controller/DatabaseController.java:[55,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.controller.DatabaseController
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[26,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[36,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[40,21] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[52,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[52,49] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[55,16] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[55,64] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[57,92] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[61,34] cannot find symbol
#   symbol:   method builder()
#   location: class com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[62,25] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[63,31] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[67,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[67,67] cannot find symbol
#   symbol:   method getId()
#   location: variable saved of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[75,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[80,21] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[86,16] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[87,31] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[89,16] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[90,38] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[92,96] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[95,37] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable dto of type com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[99,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[99,69] cannot find symbol
#   symbol:   method getId()
#   location: variable updated of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[107,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[111,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[118,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[125,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[127,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.ServiceService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[142,43] cannot find symbol
#   symbol:   method getId()
#   location: variable s of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[143,17] no suitable method found for collect(java.util.stream.Collector<java.lang.CharSequence,capture#3 of ?,java.lang.String>)
#     method java.util.stream.Stream.<R>collect(java.util.function.Supplier<R>,java.util.function.BiConsumer<R,? super java.lang.Object>,java.util.function.BiConsumer<R,R>) is not applicable
#       (cannot infer type-variable(s) R
#         (actual and formal argument lists differ in length))
#     method java.util.stream.Stream.<R,A>collect(java.util.stream.Collector<? super java.lang.Object,A,R>) is not applicable
#       (cannot infer type-variable(s) R,A
#         (argument mismatch; java.util.stream.Collector<java.lang.CharSequence,capture#4 of ?,java.lang.String> cannot be converted to java.util.stream.Collector<? super java.lang.Object,A,R>))
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[150,26] cannot find symbol
#   symbol:   method builder()
#   location: class com.daleelteq.booking.dto.ServiceDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[151,28] cannot find symbol
#   symbol:   method getId()
#   location: variable service of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[152,29] cannot find symbol
#   symbol:   method getLib()
#   location: variable service of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[153,35] cannot find symbol
#   symbol:   method getTimeValue()
#   location: variable service of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/ServiceService.java:[154,35] cannot find symbol
#   symbol:   method getCreatedAt()
#   location: variable service of type com.daleelteq.booking.domain.Service
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[27,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[37,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[41,21] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[53,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[53,50] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.EmployeeDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[55,37] cannot find symbol
#   symbol:   method builder()
#   location: class com.daleelteq.booking.domain.Employee
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[56,25] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.EmployeeDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[60,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[60,68] cannot find symbol
#   symbol:   method getId()
#   location: variable saved of type com.daleelteq.booking.domain.Employee
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[68,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[73,21] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[79,16] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.EmployeeDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[80,32] cannot find symbol
#   symbol:   method getLib()
#   location: variable dto of type com.daleelteq.booking.dto.EmployeeDto
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[84,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[84,70] cannot find symbol
#   symbol:   method getId()
#   location: variable updated of type com.daleelteq.booking.domain.Employee
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[92,9] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [ERROR] /C:/Users/Daleelteeq/Documents/from 21 November 2025 - Med Youssef Zehani/DaleelTeq-Booking-Simulation-Service-/src/main/java/com/daleelteq/booking/service/EmployeeService.java:[96,13] cannot find symbol
#   symbol:   variable log
#   location: class com.daleelteq.booking.service.EmployeeService
# [INFO] 100 errors
# [INFO] -------------------------------------------------------------

# %% [markdown]
# ## `prompt 22`

# %% [markdown]
# that unfortunately didn't fix the whole problem as now building the project shows errors
# here's what happens when I run build project:
# Executing pre-compile tasks…
# Too many modules require recompilation, forcing full project rebuild
# Cleaning output directories…
# Running 'before' tasks
# Checking sources
# Copying resources… [booking-service]
# Updating dependency information… [booking-service]
# Parsing java… [booking-service]
# java: java.lang.ClassNotFoundException: lombok.launch.AnnotationProcessor
# java: java.lang.ClassNotFoundException: lombok.launch.AnnotationProcessor
# Errors occurred while compiling module 'booking-service'
# javac 25.0.1 was used to compile java sources
# Finished, saving caches…
# Executing post-compile tasks…
# Synchronizing output directories…
# 14/01/2026 12:18 - Build completed with 2 errors and 0 warnings in 3 sec, 678 ms

# %% [markdown]
# ## `prompt 23`

# %% [markdown]
# I have installed locally mvn , you can now use mvn not the executable /mvnw
# update all files of documentation that use /mvnw in favor of mvn
# and try to remove redundant information
# making the documentation still detailed
# but especially clear to help with testing
# I still have yet to run the project
# I still haven't configured the database or added the user for db
# I want to have minimal files to navigate and not 20 files that will make me lose focus
# the last lombok_fix_summary should be deleted
# the other fixes will remain for now but would be deleted later on
#
# I want to test running the project without the database config first to see if there are some other obvious errors
# after that I will proceed to create the database config
# and then run the project again after I set the right env files

# %% [markdown]
# ## `prompt 24`

# %% [markdown]
# delete CLEANUP_CHECKLIST.md
# CLEANUP_REPORT.md
# CODEBASE_STATUS.md
# COMPILATION_FIX_GUIDE.md
# COMPLETE_ERROR_FIX_CHECKLIST.md
# DETAILED_COMPILATION_FIXES.md
# DOCUMENTATION_INDEX.md (old version)
# ERROR_FIXES_REPORT.md
# ERROR_FIX_REPORT.md
# FILES_INVENTORY.md
# FILE_VERIFICATION_REPORT.md
# FINAL_CHECKLIST.md
# FINAL_CLEANUP_REPORT.md
# GENERATION_SUMMARY.md
# PROJECT_CHECKLIST.md
# PROJECT_COMPLETION_REPORT.md
# PROJECT_GENERATION_COMPLETE.md
# QUICK_CLEANUP_SUMMARY.md
# VERIFICATION_CHECKLIST.md
#
# keep REST_CONTROLLERS_IMPLEMENTATION.md
# TESTING_GUIDE.md, QUICKSTART.md, and README.md.
#
# don't delete the notebooks
#
# project_status remains for now but would be deleted later
#
# if you want to delete other files confirm with me first

# %% [markdown]
# ## `prompt 25`

# %% [markdown]
# -[x] created booking_user db user with password
#
# this was verified with my password
#
# the db is created with another password other than changeme using the following command; as the db is already created:
# CREATE DATABASE booking_db;
# CREATE USER booking_user WITH PASSWORD 'changeme';
# GRANT ALL PRIVILEGES ON DATABASE booking_db TO booking_user;
# \q
#
#
# > when running the following command:
# psql -U booking_user -d booking_db -f src/main/resources/db/schema-postgres18.sql
#
# a lot of errors appear
# it seems like booking_user is denied permission to create the db which seems to be strange
#
#
#
# below is the console log after running the previous command:
# Password for user booking_user:
#
# psql:src/main/resources/db/schema-postgres18.sql:6: NOTICE:  table "es_notification" does not exist, skipping
# DROP TABLE
# psql:src/main/resources/db/schema-postgres18.sql:7: NOTICE:  table "rendez_vous" does not exist, skipping
# DROP TABLE
# psql:src/main/resources/db/schema-postgres18.sql:8: NOTICE:  table "employee_x_services" does not exist, skipping
# DROP TABLE
# psql:src/main/resources/db/schema-postgres18.sql:9: NOTICE:  table "services" does not exist, skipping
# DROP TABLE
# psql:src/main/resources/db/schema-postgres18.sql:10: NOTICE:  table "employees" does not exist, skipping
# DROP TABLE
# psql:src/main/resources/db/schema-postgres18.sql:11: NOTICE:  table "clients" does not exist, skipping
# DROP TABLE
# psql:src/main/resources/db/schema-postgres18.sql:20: ERROR:  permission denied for schema public
# LINE 1: CREATE TABLE services (
#                      ^
# psql:src/main/resources/db/schema-postgres18.sql:28: ERROR:  permission denied for schema public
# LINE 1: CREATE TABLE employees (
#                      ^
# psql:src/main/resources/db/schema-postgres18.sql:37: ERROR:  permission denied for schema public
# LINE 1: CREATE TABLE clients (
#                      ^
# psql:src/main/resources/db/schema-postgres18.sql:54: ERROR:  syntax error at or near "end"
# LINE 8:     end TIME NOT NULL,
#             ^
# psql:src/main/resources/db/schema-postgres18.sql:57: ERROR:  relation "employee_x_services" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:58: ERROR:  relation "employee_x_services" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:59: ERROR:  relation "employee_x_services" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:60: ERROR:  relation "employee_x_services" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:72: ERROR:  permission denied for schema public
# LINE 1: CREATE TABLE rendez_vous (
#                      ^
# psql:src/main/resources/db/schema-postgres18.sql:75: ERROR:  relation "rendez_vous" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:76: ERROR:  relation "rendez_vous" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:77: ERROR:  relation "rendez_vous" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:90: ERROR:  permission denied for schema public
# LINE 1: CREATE TABLE es_notification (
#                      ^
# psql:src/main/resources/db/schema-postgres18.sql:93: ERROR:  relation "es_notification" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:94: ERROR:  relation "es_notification" does not exist
# psql:src/main/resources/db/schema-postgres18.sql:103: ERROR:  relation "services" does not exist
# LINE 1: INSERT INTO services (lib, time_value) VALUES
#                     ^
# psql:src/main/resources/db/schema-postgres18.sql:110: ERROR:  relation "employees" does not exist
# LINE 1: INSERT INTO employees (lib) VALUES
#                     ^
# psql:src/main/resources/db/schema-postgres18.sql:117: ERROR:  relation "clients" does not exist
# LINE 1: INSERT INTO clients (lib, number) VALUES
#                     ^

# %% [markdown]
# ## `prompt 26`

# %% [markdown]
# employee_x_services start_time end_time must also be updated on their backend code of entity and when necessary to mitigate the db changes that used to be start end ( here end is forbidden thus variables of db were changed into start_time end_time)
# employee_x_services start_time end_time must match the entity which wasn't changed after altering the table columns
#
# setup-db-permissions.sql was created to fix schema-postgres18.sql but it also has errors:
# when running: psql -U postgres -d booking_db -f setup-db-permissions.sql
# here's the log below:
# Password for user postgres:
#
# GRANT
# GRANT
# ALTER DEFAULT PRIVILEGES
# ALTER DEFAULT PRIVILEGES
# psql:setup-db-permissions.sql:11: ERROR:  syntax error at or near "INDEXES"
# LINE 1: ... DEFAULT PRIVILEGES IN SCHEMA public GRANT ALL ON INDEXES TO...
#                                                              ^
# GRANT
# GRANT
# Permissions granted successfully to booking_user
#
# the last line is an echo not a signification of success

# %% [markdown]
# ## `prompt 27`

# %% [markdown]
# update documentation to include the correct db_config of:
#
# # 1. Grant permissions (as postgres superuser)
# psql -U postgres -d booking_db -f setup-db-permissions.sql
#
# # 2. Create schema (as booking_user)
# psql -U booking_user -d booking_db -f src/main/resources/db/schema-postgres18.sql
#
# # 3. Verify tables
# psql -U booking_user -d booking_db -c "\dt"
#
#
#
# the changing of variable start end in employee_x_services wasn't effective
# you should check for all occurrences of start end related to employee_x_services in all files
# start_time end_time
#
# apart from that you can find other errors related to those variables which need to be fixed all
# I tried to type in the dtofile fixing the old errors
# it used to be:
#                 .startTime(dto.getStart())
#                 .endTime(computedEnd)
# I tried changing into:
# .startTime(dto.getStartTime())
#                 .endTime(dto.getEndTime())
# but i didn't include the other consequent changes to the code that you need to automize
# (the code needs the other subsequent changes to work of getStart getEnd and others this for the dto)
#
# also changes must include all concerned files in the error
#
#
# proof is the errors when running the project as the log below proves that you copilot haven't correctly fixed
# the (employee_x_services start_time end_time must also be updated on their backend code of entity)
# ---------------------------------------------------------
# [ERROR] COMPILATION ERROR :
# [INFO] -------------------------------------------------------------
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[79,15] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[91,35] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[93,15] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[93,71] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[97,31] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[121,26] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[129,36] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable saved of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[129,54] error: cannot find symbol
#   symbol:   method getEnd()
#   location: variable saved of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[150,15] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[151,36] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[151,61] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[151,77] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[170,14] error: cannot find symbol
#   symbol:   method setStart(LocalTime)
#   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[171,14] error: cannot find symbol
#   symbol:   method setEnd(LocalTime)
#   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[252,25] error: cannot find symbol
#   symbol:   method getStart()
#   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[253,23] error: cannot find symbol
#   symbol:   method getEnd()
#   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\controller\rest\EmployeeXServiceRestController.java:[107,20] error: cannot find symbol
#   symbol:   method start(dto.getSta[...] null)
#   location: class EmployeeXServiceDtoBuilder
# [INFO] 17 errors
# [INFO] -------------------------------------------------------------
# [INFO] ------------------------------------------------------------------------
# [INFO] BUILD FAILURE
# [INFO] ------------------------------------------------------------------------
# [INFO] Total time:  8.965 s
# [INFO] Finished at: 2026-01-28T13:06:48+01:00
# [INFO] ------------------------------------------------------------------------
# [ERROR] Failed to execute goal org.apache.maven.plugins:maven-compiler-plugin:3.14.1:compile (default-compile) on project booking-simulation-service: Compilation failure: Compilation failure:
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[79,15] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[91,35] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[93,15] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[93,71] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[97,31] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[121,26] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[129,36] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable saved of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[129,54] error: cannot find symbol
# [ERROR]   symbol:   method getEnd()
# [ERROR]   location: variable saved of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[150,15] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[151,36] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[151,61] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable dto of type EmployeeXServiceDto
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[151,77] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[170,14] error: cannot find symbol
# [ERROR]   symbol:   method setStart(LocalTime)
# [ERROR]   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[171,14] error: cannot find symbol
# [ERROR]   symbol:   method setEnd(LocalTime)
# [ERROR]   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[252,25] error: cannot find symbol
# [ERROR]   symbol:   method getStart()
# [ERROR]   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\service\EmployeeXServiceService.java:[253,23] error: cannot find symbol
# [ERROR]   symbol:   method getEnd()
# [ERROR]   location: variable es of type EmployeeXService
# [ERROR] C:\Users\Daleelteeq\Documents\from 21 November 2025 - Med Youssef Zehani\DaleelTeq-Booking-Simulation-Service-\src\main\java\com\daleelteq\booking\controller\rest\EmployeeXServiceRestController.java:[107,20] error: cannot find symbol
# [ERROR]   symbol:   method start(dto.getSta[...] null)
# [ERROR]   location: class EmployeeXServiceDtoBuilder
# [ERROR] -> [Help 1]
# [ERROR]
# [ERROR] To see the full stack trace of the errors, re-run Maven with the -e switch.
# [ERROR] Re-run Maven using the -X switch to enable full debug logging.
# [ERROR]
# [ERROR] For more information about the errors and possible solutions, please read the following articles:
# [ERROR] [Help 1] http://cwiki.apache.org/confluence/display/MAVEN/MojoFailureException

# %% [markdown]
# ## `prompt 28`

# %% [markdown]
# you didn't include the right documentation in readme.md  related to the database
# in 3. Database Setup  after Step 1: Create Database and User
# the changes should happen within Step 2: Load Schema or before it should be completely changed into including a version of the code below:
# # 1. Grant permissions (as postgres superuser)
# psql -U postgres -d booking_db -f setup-db-permissions.sql
#
# # 2. Create schema (as booking_user)
# psql -U booking_user -d booking_db -f src/main/resources/db/schema-postgres18.sql
#
# # 3. Verify tables
# psql -U booking_user -d booking_db -c "\dt"
#
# also when running the project there's seems to be an authentication password error while
# I'm both sure of the username and password both tested
# from .env file
# I have verified through testing that the problem is from loading the .env file
# which isn't loading and from the (env:if_fails) the if_fails here is the one that's working
# and the reason it fails password authentication is because I didn't put my password
# within the if_fails
#
# [FATAL: password authentication failed for user "booking_user"]
#
# the .DotenvEnvironmentPostProcessor   : isn't working here
#
# and we need a way to either make it work or see a workaround or another way
# I'd rather we make it work

# %% [markdown]
# ## `prompt 29`

# %% [markdown]
# wrong not fixed, import org.springframework.boot.env.EnvironmentPostProcessor; shows errors also
# DotenvEnvironmentPostProcessor.java:[28,55] [removal] EnvironmentPostProcessor in org.springframework.boot.env has been deprecated and marked for removal
# we need to fix this
#
# to check for errors you need to mvn run and then wait for hikari
# HikariPool-1 - Starting...
# FATAL: password authentication failed for user "user_not_found"
#
# when "user_not_found" is found it means the user hadn't been loaded from env
# I put the default username as user_not_found to easily pinpoint such errors
#
# please never say the problem is fixed when you aren't even sure
# you even provided misinformation about hikari when you weren't even sure about the outcome

# %% [markdown]
# ## `prompt 30`

# %% [markdown]
# when running the project I get the log below
#
# ConfigServletWebServerApplicationContext : Exception encountered during context initialization - cancelling refresh attempt: org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'requestMappingHandlerMapping' defined in class path resource [org/springframework/boot/webmvc/autoconfigure/WebMvcAutoConfiguration$EnableWebMvcConfiguration.class]: Ambiguous mapping. Cannot map 'clientRestController' method
# com.daleelteq.booking.controller.rest.ClientRestController#getAllClients()
# to {GET [/api/clients]}: There is already 'clientController' bean method
# com.daleelteq.booking.controller.ClientController#getAllClients() mapped.
# 2026-01-28T15:17:44.808+01:00  INFO 11612 --- [DaleelTeq-Booking-Service] [  restartedMain] j.LocalContainerEntityManagerFactoryBean : Closing JPA EntityManagerFactory for persistence unit 'default'
# 2026-01-28T15:17:44.812+01:00  INFO 11612 --- [DaleelTeq-Booking-Service] [  restartedMain] com.zaxxer.hikari.HikariDataSource       : HikariPool-1 - Shutdown initiated...
# 2026-01-28T15:17:44.820+01:00  INFO 11612 --- [DaleelTeq-Booking-Service] [  restartedMain] com.zaxxer.hikari.HikariDataSource       : HikariPool-1 - Shutdown completed.
# 2026-01-28T15:17:44.823+01:00  INFO 11612 --- [DaleelTeq-Booking-Service] [  restartedMain] o.apache.catalina.core.StandardService   : Stopping service [Tomcat]
# 2026-01-28T15:17:44.843+01:00  INFO 11612 --- [DaleelTeq-Booking-Service] [  restartedMain] .s.b.a.l.ConditionEvaluationReportLogger :
#
# Error starting ApplicationContext. To display the condition evaluation report re-run your application with 'debug' enabled.
# 2026-01-28T15:17:44.867+01:00 ERROR 11612 --- [DaleelTeq-Booking-Service] [  restartedMain] o.s.boot.SpringApplication               : Application run failed
#
# org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'requestMappingHandlerMapping' defined in class path resource [org/springframework/boot/webmvc/autoconfigure/WebMvcAutoConfiguration$EnableWebMvcConfiguration.class]: Ambiguous mapping. Cannot map 'clientRestController' method
# com.daleelteq.booking.controller.rest.ClientRestController#getAllClients()
# to {GET [/api/clients]}: There is already 'clientController' bean method
# com.daleelteq.booking.controller.ClientController#getAllClients() mapped.
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.initializeBean(AbstractAutowireCapableBeanFactory.java:1817) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.doCreateBean(AbstractAutowireCapableBeanFactory.java:603) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.createBean(AbstractAutowireCapableBeanFactory.java:525) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.lambda$doGetBean$0(AbstractBeanFactory.java:333) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultSingletonBeanRegistry.getSingleton(DefaultSingletonBeanRegistry.java:371) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.doGetBean(AbstractBeanFactory.java:331) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.getBean(AbstractBeanFactory.java:196) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.instantiateSingleton(DefaultListableBeanFactory.java:1218) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.preInstantiateSingleton(DefaultListableBeanFactory.java:1184) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.preInstantiateSingletons(DefaultListableBeanFactory.java:1121) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.context.support.AbstractApplicationContext.finishBeanFactoryInitialization(AbstractApplicationContext.java:983) ~[spring-context-7.0.1.jar:7.0.1]
# 	at org.springframework.context.support.AbstractApplicationContext.refresh(AbstractApplicationContext.java:620) ~[spring-context-7.0.1.jar:7.0.1]
# 	at org.springframework.boot.web.server.servlet.context.ServletWebServerApplicationContext.refresh(ServletWebServerApplicationContext.java:143) ~[spring-boot-web-server-4.0.0.jar:4.0.0]
# 	at org.springframework.boot.SpringApplication.refresh(SpringApplication.java:765) ~[spring-boot-4.0.0.jar:4.0.0]
# 	at org.springframework.boot.SpringApplication.refreshContext(SpringApplication.java:454) ~[spring-boot-4.0.0.jar:4.0.0]
# 	at org.springframework.boot.SpringApplication.run(SpringApplication.java:321) ~[spring-boot-4.0.0.jar:4.0.0]
# 	at com.daleelteq.booking.BookingApplication.main(BookingApplication.java:17) ~[classes/:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:104) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:565) ~[na:na]
# 	at org.springframework.boot.devtools.restart.RestartLauncher.run(RestartLauncher.java:52) ~[spring-boot-devtools-4.0.0.jar:4.0.0]
# Caused by: java.lang.IllegalStateException: Ambiguous mapping. Cannot map 'clientRestController' method
# com.daleelteq.booking.controller.rest.ClientRestController#getAllClients()
# to {GET [/api/clients]}: There is already 'clientController' bean method
# com.daleelteq.booking.controller.ClientController#getAllClients() mapped.
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping$MappingRegistry.validateMethodMapping(AbstractHandlerMethodMapping.java:645) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping$MappingRegistry.register(AbstractHandlerMethodMapping.java:606) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.registerHandlerMethod(AbstractHandlerMethodMapping.java:327) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.mvc.method.annotation.RequestMappingHandlerMapping.registerHandlerMethod(RequestMappingHandlerMapping.java:459) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.mvc.method.annotation.RequestMappingHandlerMapping.registerHandlerMethod(RequestMappingHandlerMapping.java:80) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.lambda$detectHandlerMethods$1(AbstractHandlerMethodMapping.java:294) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at java.base/java.util.LinkedHashMap.forEach(LinkedHashMap.java:987) ~[na:na]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.detectHandlerMethods(AbstractHandlerMethodMapping.java:292) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.processCandidateBean(AbstractHandlerMethodMapping.java:261) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.initHandlerMethods(AbstractHandlerMethodMapping.java:220) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.afterPropertiesSet(AbstractHandlerMethodMapping.java:208) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.mvc.method.annotation.RequestMappingHandlerMapping.afterPropertiesSet(RequestMappingHandlerMapping.java:158) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.invokeInitMethods(AbstractAutowireCapableBeanFactory.java:1864) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.initializeBean(AbstractAutowireCapableBeanFactory.java:1813) ~[spring-beans-7.0.1.jar:7.0.1]

# %% [markdown]
# ## `prompt 31`

# %% [markdown]
# you need to update the documentation of readme to include the api & ui differences
# also:
# when running here's the log error (this problem):
# Exception encountered during context initialization - cancelling refresh attempt: org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'requestMappingHandlerMapping' defined in class path resource [org/springframework/boot/webmvc/autoconfigure/WebMvcAutoConfiguration$EnableWebMvcConfiguration.class]: Ambiguous mapping. Cannot map 'webIndexController' method
# com.daleelteq.booking.controller.web.WebIndexController#index(Model)
# to {GET [/]}: There is already 'UIController' bean method
# com.daleelteq.booking.controller.UIController#index() mapped.
# 2026-01-28T16:27:23.784+01:00  INFO 13208 --- [DaleelTeq-Booking-Service] [  restartedMain] j.LocalContainerEntityManagerFactoryBean : Closing JPA EntityManagerFactory for persistence unit 'default'
# 2026-01-28T16:27:23.787+01:00  INFO 13208 --- [DaleelTeq-Booking-Service] [  restartedMain] com.zaxxer.hikari.HikariDataSource       : HikariPool-1 - Shutdown initiated...
# 2026-01-28T16:27:23.794+01:00  INFO 13208 --- [DaleelTeq-Booking-Service] [  restartedMain] com.zaxxer.hikari.HikariDataSource       : HikariPool-1 - Shutdown completed.
# 2026-01-28T16:27:23.798+01:00  INFO 13208 --- [DaleelTeq-Booking-Service] [  restartedMain] o.apache.catalina.core.StandardService   : Stopping service [Tomcat]
# 2026-01-28T16:27:23.806+01:00  INFO 13208 --- [DaleelTeq-Booking-Service] [  restartedMain] .s.b.a.l.ConditionEvaluationReportLogger :
#
# Error starting ApplicationContext. To display the condition evaluation report re-run your application with 'debug' enabled.
# 2026-01-28T16:27:23.841+01:00 ERROR 13208 --- [DaleelTeq-Booking-Service] [  restartedMain] o.s.boot.SpringApplication               : Application run failed
#
# org.springframework.beans.factory.BeanCreationException: Error creating bean with name 'requestMappingHandlerMapping' defined in class path resource [org/springframework/boot/webmvc/autoconfigure/WebMvcAutoConfiguration$EnableWebMvcConfiguration.class]: Ambiguous mapping. Cannot map 'webIndexController' method
# com.daleelteq.booking.controller.web.WebIndexController#index(Model)
# to {GET [/]}: There is already 'UIController' bean method
# com.daleelteq.booking.controller.UIController#index() mapped.
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.initializeBean(AbstractAutowireCapableBeanFactory.java:1817) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.doCreateBean(AbstractAutowireCapableBeanFactory.java:603) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.createBean(AbstractAutowireCapableBeanFactory.java:525) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.lambda$doGetBean$0(AbstractBeanFactory.java:333) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultSingletonBeanRegistry.getSingleton(DefaultSingletonBeanRegistry.java:371) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.doGetBean(AbstractBeanFactory.java:331) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractBeanFactory.getBean(AbstractBeanFactory.java:196) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.instantiateSingleton(DefaultListableBeanFactory.java:1218) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.preInstantiateSingleton(DefaultListableBeanFactory.java:1184) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.DefaultListableBeanFactory.preInstantiateSingletons(DefaultListableBeanFactory.java:1121) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.context.support.AbstractApplicationContext.finishBeanFactoryInitialization(AbstractApplicationContext.java:983) ~[spring-context-7.0.1.jar:7.0.1]
# 	at org.springframework.context.support.AbstractApplicationContext.refresh(AbstractApplicationContext.java:620) ~[spring-context-7.0.1.jar:7.0.1]
# 	at org.springframework.boot.web.server.servlet.context.ServletWebServerApplicationContext.refresh(ServletWebServerApplicationContext.java:143) ~[spring-boot-web-server-4.0.0.jar:4.0.0]
# 	at org.springframework.boot.SpringApplication.refresh(SpringApplication.java:765) ~[spring-boot-4.0.0.jar:4.0.0]
# 	at org.springframework.boot.SpringApplication.refreshContext(SpringApplication.java:454) ~[spring-boot-4.0.0.jar:4.0.0]
# 	at org.springframework.boot.SpringApplication.run(SpringApplication.java:321) ~[spring-boot-4.0.0.jar:4.0.0]
# 	at com.daleelteq.booking.BookingApplication.main(BookingApplication.java:17) ~[classes/:na]
# 	at java.base/jdk.internal.reflect.DirectMethodHandleAccessor.invoke(DirectMethodHandleAccessor.java:104) ~[na:na]
# 	at java.base/java.lang.reflect.Method.invoke(Method.java:565) ~[na:na]
# 	at org.springframework.boot.devtools.restart.RestartLauncher.run(RestartLauncher.java:52) ~[spring-boot-devtools-4.0.0.jar:4.0.0]
# Caused by: java.lang.IllegalStateException: Ambiguous mapping. Cannot map 'webIndexController' method
# com.daleelteq.booking.controller.web.WebIndexController#index(Model)
# to {GET [/]}: There is already 'UIController' bean method
# com.daleelteq.booking.controller.UIController#index() mapped.
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping$MappingRegistry.validateMethodMapping(AbstractHandlerMethodMapping.java:645) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping$MappingRegistry.register(AbstractHandlerMethodMapping.java:606) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.registerHandlerMethod(AbstractHandlerMethodMapping.java:327) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.mvc.method.annotation.RequestMappingHandlerMapping.registerHandlerMethod(RequestMappingHandlerMapping.java:459) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.mvc.method.annotation.RequestMappingHandlerMapping.registerHandlerMethod(RequestMappingHandlerMapping.java:80) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.lambda$detectHandlerMethods$1(AbstractHandlerMethodMapping.java:294) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at java.base/java.util.LinkedHashMap.forEach(LinkedHashMap.java:987) ~[na:na]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.detectHandlerMethods(AbstractHandlerMethodMapping.java:292) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.processCandidateBean(AbstractHandlerMethodMapping.java:261) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.initHandlerMethods(AbstractHandlerMethodMapping.java:220) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.handler.AbstractHandlerMethodMapping.afterPropertiesSet(AbstractHandlerMethodMapping.java:208) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.web.servlet.mvc.method.annotation.RequestMappingHandlerMapping.afterPropertiesSet(RequestMappingHandlerMapping.java:158) ~[spring-webmvc-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.invokeInitMethods(AbstractAutowireCapableBeanFactory.java:1864) ~[spring-beans-7.0.1.jar:7.0.1]
# 	at org.springframework.beans.factory.support.AbstractAutowireCapableBeanFactory.initializeBean(AbstractAutowireCapableBeanFactory.java:1813) ~[spring-beans-7.0.1.jar:7.0.1]

# %% [markdown]
# ## `prompt 32`

# %% [markdown]
# fix documentation of readme to include all api ui transcations (if readme doesn't contain)

# %% [markdown]
# ## `prompt 33`

# %% [markdown]
# ## `prompt 34`
